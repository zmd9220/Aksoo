# %%
import cv2 
import os
import time
import uuid

# %%
Images_Path = 'Tensorflow/workspace/images/collectedimages'

# %%
labels = ['hello', 'thanks', 'yes', 'no', 'iloveyou']
number_imgs = 15

# %%
for label in labels:
    # !mkdir {'Tensorflow\workspace\images\collectedimages\\' + label}
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        ret, frame = cap.read()
        imgname = os.path.join(Images_Path, label, label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
# Out:
# 하위 디렉터리 또는 파일 Tensorflow\workspace\images\collectedimages\hello이(가) 이미 있습니다.
# Collecting images for hello
# 하위 디렉터리 또는 파일 Tensorflow\workspace\images\collectedimages\thanks이(가) 이미 있습니다.
# Collecting images for thanks
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-60e22444c84f> in <module>
#       3     cap = cv2.VideoCapture(0)
#       4     print('Collecting images for {}'.format(label))
# ----> 5     time.sleep(5)
#       6     for imgnum in range(number_imgs):
#       7         ret, frame = cap.read()
#
# KeyboardInterrupt:

# %%
# 1234
